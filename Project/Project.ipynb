# %% [markdown]
# <a href="https://colab.research.google.com/github/Ananassio/Data-Science_lab/blob/main/Project/Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
X=pd.read_csv('train_sessions.csv')

# %%
X.head()
# Out:
#    session_id  item_id                     date
# 0           3   9655.0  2020-12-18 21:25:00.373
# 1           3   9655.0  2020-12-18 21:19:48.093
# 2          13  15654.0  2020-03-13 19:35:27.136
# 3          18  18316.0  2020-08-26 19:18:30.833
# 4          18   2507.0  2020-08-26 19:16:31.211

# %%
y=pd.read_csv('train_purchases.csv')

# %%
y.head()
# Out:
#    session_id  item_id                     date
# 0           3    15085  2020-12-18 21:26:47.986
# 1          13    18626  2020-03-13 19:36:15.507
# 2          18    24911  2020-08-26 19:20:32.049
# 3          19    12534   2020-11-02 17:16:45.92
# 4          24    13226  2020-02-26 18:27:44.114

# %%
item_features = pd.read_csv('item_features.csv')

# %%
item_features.head()
# Out:
#    item_id  feature_category_id  feature_value_id
# 0        2                   56               365
# 1        2                   62               801
# 2        2                   68               351
# 3        2                   33               802
# 4        2                   72                75

# %%
X.groupby('session_id').head()
# Out:
#         session_id  item_id                     date
# 0                3   9655.0  2020-12-18 21:25:00.373
# 1                3   9655.0  2020-12-18 21:19:48.093
# 2               13  15654.0  2020-03-13 19:35:27.136
# 3               18  18316.0  2020-08-26 19:18:30.833
# 4               18   2507.0  2020-08-26 19:16:31.211
# ...            ...      ...                      ...
# 347992      324965   9219.0  2021-04-26 10:30:26.631
# 347993      324965  14865.0  2021-04-26 10:30:23.659
# 347994      324965   9219.0  2021-04-26 10:30:08.652
# 347995      324965   2325.0  2021-04-26 10:30:19.529
# 347996          32      NaN                      NaN
#
# [214447 rows x 3 columns]

# %%
y.tail()
# Out:
#         session_id  item_id                     date
# 999995     4439986     2915  2021-05-13 11:56:37.464
# 999996     4439990     8786  2020-08-22 14:28:22.382
# 999997     4439994    21630  2020-11-27 20:10:28.961
# 999998     4439999    16962  2020-11-27 11:01:41.356
# 999999     4440001    16631  2020-10-30 23:46:05.218

# %%
X.tail()
# Out:
#          session_id  item_id                     date
# 4743815     4440001    20409  2020-10-30 23:37:20.658
# 4743816     4440001    14155  2020-10-30 23:31:56.607
# 4743817     4440001    14303  2020-10-30 23:36:17.934
# 4743818     4440001    27852  2020-10-30 23:39:55.186
# 4743819     4440001      305  2020-10-30 23:27:37.873

# %%
X['day']=pd.to_datetime(X['date']).dt.day_name()

# %%
pd.to_datetime(X['date']).dt.hour
# Out:
# 0          21
# 1          21
# 2          19
# 3          19
# 4          19
#            ..
# 4743815    23
# 4743816    23
# 4743817    23
# 4743818    23
# 4743819    23
# Name: date, Length: 4743820, dtype: int64

# %%
X['part_of_day'] = (pd.to_datetime(X['date']).dt.hour % 24 + 4) // 4
X['part_of_day'].replace({1: 'Late Night',
                      2: 'Early Morning',
                      3: 'Morning',
                      4: 'Noon',
                      5: 'Evening',
                      6: 'Night'}, inplace=True)

# %%
X
# Out:
#          session_id  item_id                     date part_of_day        day
# 0                 3     9655  2020-12-18 21:25:00.373       Night     Friday
# 1                 3     9655  2020-12-18 21:19:48.093       Night     Friday
# 2                13    15654  2020-03-13 19:35:27.136     Evening     Friday
# 3                18    18316  2020-08-26 19:18:30.833     Evening  Wednesday
# 4                18     2507  2020-08-26 19:16:31.211     Evening  Wednesday
# ...             ...      ...                      ...         ...        ...
# 4743815     4440001    20409  2020-10-30 23:37:20.658       Night     Friday
# 4743816     4440001    14155  2020-10-30 23:31:56.607       Night     Friday
# 4743817     4440001    14303  2020-10-30 23:36:17.934       Night     Friday
# 4743818     4440001    27852  2020-10-30 23:39:55.186       Night     Friday
# 4743819     4440001      305  2020-10-30 23:27:37.873       Night     Friday
#
# [4743820 rows x 5 columns]
